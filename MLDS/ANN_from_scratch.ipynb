# %% [markdown]
# # Neural Network from Scratch

# %% [markdown]
# # 1. Pendahuluan
#
# Notebook ini merupakan latihan praktik mengimplementasikan ANN tanpa package _Deep Learning_ (seperti keras dan tensor flow). Alasan mengapa dalam notebook ini kita tidak akan menggunakan package _Deep Learning_ yang tersedia karena target dari notebook ini adalah peserta dapat mengimplementasikan beberapa persamaan yang menjadi jantung dalam algoritma ANN, seperti:
#
# 1. Implementasi _Sigmoid Function_
# 2. Implementasi perhitungan _Score dan Prediction_
# 3. Implementasi _Error Function_
# 4. Implementasi _Gradient Descent_
#
# Beberapa tahap akan dilalui untuk menyelesaikan notebook ini, antara lain:
#
# 1. Mempersiapkan perlengkapan yang akan diperlukan
# 2. Memuat dan mengenal dataset
# 3. Mempersiapkan beberapa fungsi yang akan diperlukan
# 4. Implementasi algoritma ANN (Training)
# 5. Kesimpulan

# %% [markdown]
# # 2. Mempersiapkan Perlengkapan yang Akan Diperlukan
#
# ## 2.1. Import Package
#
# Beberapa fungsi berikut merupakan fungsi dasar yang umum digunakan dalam pemrograman machine learning. Terdapat empat buah package: numpy, pandas, matplotlib, dan seaborn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 2.2. Fungsi Untuk Visualisasi
#
# Fungsi berikut sudah dirancang untuk memudahkan kita untuk melakukan visualisasi. Saran dari saya, kalian tidak perlu memahami fungsi ini terlalu dalam, karena fokus notebook ini bukan untuk memahami fungsi ini, melainkan konsep fundamental dari implementasi **Artificial Neural Network**. Asumsikan saja beberapa fungsi ini telah dibuat oleh orang lain yang siap dipakai dalam projek kita sekarang.

# %%
def plot_points(X, y):
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s = 25, color = 'blue', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s = 25, color = 'red', edgecolor = 'k')

def display(m, b, color='g--'):
    plt.xlim(-0.05,1.05)
    plt.ylim(-0.05,1.05)
    x = np.arange(-10, 10, 0.1)
    plt.plot(x, m*x+b, color)

# %% [markdown]
# ---
# # 3. Memuat dan Mengenal Dataset
#
# Tahap ini umum dilakukan dalam pemrograman machine learning, guna memahami bagaimana rupa dataset yang kita miliki. Dalam notebook ini, dataset yang digunakan adalah berupa poin 2D yang dikelompokkan dengan dua buah label tertentu, 1 dan 0. Dataset disimpan dalam file berekstensi CSV, maka dari itu kita membutuhkan package _pandas_ untuk memuat dan melakukan eksplorasi data kita ini.

# %%
# kita load data kita
dataframe = pd.read_csv('https://raw.githubusercontent.com/rintoprie/Modul-Belajar-Coding/refs/heads/main/MLDS/generated_dataset_for_ann.csv')

# periksa tipe data dari variable data
# type(dataframe)

# %%
dataframe.describe()
# Out:
#                x1          x2       y
# count  100.000000  100.000000  100.00
# mean     0.485179    0.521849    0.45
# std      0.292469    0.292907    0.50
# min      0.005062    0.015457    0.00
# 25%      0.237540    0.285099    0.00
# 50%      0.506713    0.535995    0.00
# 75%      0.715623    0.794905    1.00
# max      0.985650    0.990054    1.00

# %%
# lihat beberapa nilai yang paling atas
dataframe.head(10)
# Out:
#          x1        x2  y
# 0  0.807440  0.657613  1
# 1  0.896091  0.568309  1
# 2  0.318003  0.093675  0
# 3  0.110052  0.367716  0
# 4  0.227935  0.265202  0
# 5  0.427108  0.243990  0
# 6  0.818015  0.973011  1
# 7  0.860731  0.393098  1
# 8  0.006952  0.892047  0
# 9  0.510747  0.631139  1

# %%
# tampilkan visualisasi sebaran data dalam grafik 2D
sns.scatterplot(x="x1", y="x2", data=dataframe, hue='y')
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %% [markdown]
# Untuk memudahkan operasi berikutnya, kita konversi dataframe yang kita miliki menjadi NumPy array

# %%
X = np.array(dataframe[['x1','x2']])
y = np.array(dataframe['y'])

# %% [markdown]
# ---
# # 4. Mempersiapkan Fungsi yang Diperlukan
#
# Kita membutuhkan beberapa fungsi dasar untuk mendukung proses training ANN kita. Dalam tahap ini kita akan membuat empat buah fungsi yaitu:
#
# 1. _Sigmoid Function_
# 2. _Prediction_
# 3. _Error Function_
# 4. _Gradient Descent_

# %% [markdown]
# ## 4.1. Sigmoid Activation Function
#
# **Actvation function** merupakan fungsi yang mengubah _score_ menjadi nilai tertentu yang kemudian akan diteruskan ke neuron selanjutnya. Nilai tertentu ini umumnya merupakan sebuah probabilitas yang memiliki rentang [0,1]. _Activation function_ yang akan kita gunakan disini adalah _sigmoid function_. Tentu terdapat banyak _activation function_ yang dapat digunakan (seperti softmax, reLu softmax, tanh, dll), namun pada kasus kita sekarang, kita ingin melakukan binary classification dengan probabilitas terentu, sehingga _sigmoid function_ sudah cukup untuk menangani permasalahan ini.
#
# _Sigmoid function_ didefinisikan sebagai berikut:
#
# $$\sigma(x) = \frac{1}{1+e^{-x}}$$
#
# Petunjuk spesifikasi fungsi:
# - **Input** : 1 buah; numpy array yang tiap-tiap elemnnya merupakan _score_ yang didapatkan neuron pada layer sebelumnya.
# - **Output** : 1 buah; numpy array yang tiap-tiap elemennya merupakan sebuah nilai probabilitas.

# %%
# implementasi fungsi aktivasi (sigmoid function)
def sigmoid(x):

    # persamaan sigmoid function
    return 1 / (1 + np.exp(-x))

# %% [markdown]
# ## 4.2. Prediction
#
# **Prediction** berupa sebuah nilai yang menunjukkan probabilitas input merupakan kelompok 1 atau kelompok 0. _Prediction_ dapat dilakukan dengan cara menghitung _score_ yang kemudian kita konversikan menjadi nilai probabilitas menggunakan fungsi _sigmoid_ yang telah kita implementasikan sebelumnya.
#
# _Prediction_  didefinisikan sebagai berikut:
#
# $$\hat{y} = \sigma(w_1 x_1 + w_2 x_2 + b)$$
#
# Petunjuk spesifikasi fungsi:
# * **Input** : 3 buah; features (x1 dan x2), weights, dan bias. Ketiganya berupa numpy array.
# * **Output** : 1 buah; numpy array yang tiap-tiap elemennya merupakan sebuah nilai prediksi.

# %%
# implementasi fungsi prediksi
def predict(features, weights, bias):

    # hitung score
    score = np.dot(features, weights)+bias

    # hitung probabilitas dan return
    return sigmoid(score)

# %% [markdown]
# ## 4.3. Error Function
#
# **Error Function** (kadang dikenal dengan _cost function_, _loss function_, _objective funtion_) merupakan sebuah fungsi yang menunjukkan seberapa buruk performa ANN kita. Semakin besar nilai _Error Function_ semakin buruk performa, dan berlaku sebaliknya. _Error function_ yang kita gunakan merupakan **Cross Entropy**, error function umum yang digunakand alam ANN dasar.
#
# _Cross Entropy_ didefinisikasn sebagai berikut:
#
# $$Error(y, \hat{y}) = - y \log(\hat{y}) - (1-y) \log(1-\hat{y})$$
#
# Petunjuk spesifikasi fungsi:
# * **Input**: 2 buah; label dan nilai prediksi. Keduanya berupa numpy array.
# * **Output**: 1 buah; numpy array yang tiap-tiap elemennya merupakan besar error tiap-tiap poin.

# %%
# implementasi error function
def error_formula(y, prediction):

    # persamaan cross entropy
    return -y*np.log(prediction) - (1-y)*np.log(1-prediction)

# %% [markdown]
# ## 4.4. Gradient Descent
#
# **Gradient Descent** merupakan salah satu algoritma dalam _optimisasi matematis_. Ide dari algoritma ini kita ingin melakukan update weights dan bias (yang notabene merupakan variable pembentuk ANN kita) untuk mendapatkan nilai error dari _error function_ yang terkecil. Untuk menemukan _gradien_ dalam _surface solution_ yang dibentuk oleh _error function_ adalah dengan mencari _first order derivative_ dari _error function_ itu sendiri. Penurunan _first order derivative_ dari _error function_ dapat dilihat di lampiran.
#
# Gradien descent didefinisikan sebagai berikut:
#
# $$ w_i \longrightarrow w_i + \alpha (y - \hat{y}) x_i$$

# %% [markdown]
# $$ b \longrightarrow b + \alpha (y - \hat{y})$$
#
# Petunjuk spesifikasi fungsi:
#
# * **Input**: 5 buah; Nilai input (X), label (y), prediksi (y_hat), weigths, bias, learn rate).
# * **Output**: 2 buah; Weight dan bias yang sudah di perbaharui.

# %%
# Gradient descent step
def gradient_descent(X, y, predictions, weights, bias, learnrate):

    # kita cari y-yhat dimasukkan kedalam delta_error menghasilkan numpy array 1D berjumlah n
    delta_error = y-predictions

    # kita ubah bentuk delta_error dari numpy array 1D (n) menjadi numpy array 2D (nx1)
    # alasan kita lakukan ini agar kita dapat melakukan product antara delta_error dan X
    # dimensi delta_error = (nx1) ; dimensi X = (nx2)
    delta_error = delta_error.reshape([100, 1])

    # update weight dan bias
    weights = weights + np.sum(learnrate * delta_error * X, axis=0)
    bias = bias + learnrate * np.sum(delta_error, axis=0)

    # kembalikan dua buah nilai sekaligus ke fungsi
    return weights, bias

# %% [markdown]
# # 5. Implementasi ANN (Training)
#
# Setelah kita mempersiapkan seluruhnya fungsi yang kita perlukan, saatnya kita implementasi ANN kita. Untuk merangkum teori yang telah dibahas sebelumnya, untuk melakukan training terdiri dari beberapa langkah berikut:
#
# 1. Inisialisasikan beberapa variable yang dibutuhkan oleh ANN.
# 2. Lakukan feedforward-propagation dengan _Prediction_.
# 3. Hitung besar error kita dengan _Error Function_.
# 4. Update _weights_ dan _bias_ dengan _Gradient Descent_.
# 5. Visualisasikan apa yang terjadi.
# 6. Ulangi langkah 2 sampai 5 sampai iterasi yang telah ditentukan.

# %%
# inisialisasikan beberapa variable yang dibutuhkan oleh ANN
weights = np.random.rand(2)
bias = 0

# learn rate merupakan variable alpha pada persamaan gradient descent
learnrate = 0.01

# epoch merupakan jumlah iterasi yang digunakan dalam melakukan gradient descent
epoch = 200

# lakukan iterasi sejumlah nilai epoch
for i in range(200):

    # kalkulasi prediksi (y_hat)
    predictions = predict(X, weights, bias)

    # hitung berapa nilai loss yang kita punya dengan melakukan mean
    loss = np.mean(error_formula(y, predictions))

    # lakukan perbaharuan nilai weights dan bias menggunakan gradient descent
    weights, bias = gradient_descent(X, y, predictions, weights, bias, learnrate)

    # tampilkan informasi yang dibutuhkan untuk melihat apa yg sebenarnya terjadi saat proses gradient descent
    display(-weights[0]/weights[1], -bias/weights[1])
    print('epoch = %02d, loss = %.3f, persamaan garis %.2fx + %.2fy + %.2f = 0' %
          (i, loss, weights[0], weights[0], bias) )

# tampilkan visualisasi hasil akhir
display(-weights[0]/weights[1], -bias/weights[1], 'black')
plot_points(X, y)
# Out:
# <ipython-input-26-589c04dc367e>:25: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('epoch = %02d, loss = %.3f, persamaan garis %.2fx + %.2fy + %.2f = 0' %
# epoch = 00, loss = 0.732, persamaan garis 0.87x + 0.87y + -0.27 = 0
# epoch = 01, loss = 0.659, persamaan garis 0.83x + 0.83y + -0.47 = 0
# epoch = 02, loss = 0.623, persamaan garis 0.82x + 0.82y + -0.61 = 0
# epoch = 03, loss = 0.605, persamaan garis 0.83x + 0.83y + -0.72 = 0
# epoch = 04, loss = 0.595, persamaan garis 0.85x + 0.85y + -0.80 = 0
# epoch = 05, loss = 0.588, persamaan garis 0.88x + 0.88y + -0.86 = 0
# epoch = 06, loss = 0.583, persamaan garis 0.92x + 0.92y + -0.92 = 0
# epoch = 07, loss = 0.578, persamaan garis 0.95x + 0.95y + -0.97 = 0
# epoch = 08, loss = 0.574, persamaan garis 0.99x + 0.99y + -1.01 = 0
# epoch = 09, loss = 0.570, persamaan garis 1.03x + 1.03y + -1.05 = 0
# epoch = 10, loss = 0.566, persamaan garis 1.06x + 1.06y + -1.09 = 0
# epoch = 11, loss = 0.562, persamaan garis 1.10x + 1.10y + -1.13 = 0
# epoch = 12, loss = 0.558, persamaan garis 1.14x + 1.14y + -1.17 = 0
# epoch = 13, loss = 0.554, persamaan garis 1.18x + 1.18y + -1.21 = 0
# epoch = 14, loss = 0.550, persamaan garis 1.21x + 1.21y + -1.24 = 0
# epoch = 15, loss = 0.546, persamaan garis 1.25x + 1.25y + -1.28 = 0
# epoch = 16, loss = 0.543, persamaan garis 1.29x + 1.29y + -1.32 = 0
# epoch = 17, loss = 0.539, persamaan garis 1.32x + 1.32y + -1.35 = 0
# epoch = 18, loss = 0.536, persamaan garis 1.36x + 1.36y + -1.39 = 0
# epoch = 19, loss = 0.532, persamaan garis 1.40x + 1.40y + -1.42 = 0
# epoch = 20, loss = 0.529, persamaan garis 1.43x + 1.43y + -1.45 = 0
# epoch = 21, loss = 0.526, persamaan garis 1.47x + 1.47y + -1.49 = 0
# epoch = 22, loss = 0.522, persamaan garis 1.50x + 1.50y + -1.52 = 0
# epoch = 23, loss = 0.519, persamaan garis 1.53x + 1.53y + -1.56 = 0
# epoch = 24, loss = 0.516, persamaan garis 1.57x + 1.57y + -1.59 = 0
# epoch = 25, loss = 0.513, persamaan garis 1.60x + 1.60y + -1.62 = 0
# epoch = 26, loss = 0.510, persamaan garis 1.63x + 1.63y + -1.65 = 0
# epoch = 27, loss = 0.507, persamaan garis 1.67x + 1.67y + -1.69 = 0
# epoch = 28, loss = 0.504, persamaan garis 1.70x + 1.70y + -1.72 = 0
# epoch = 29, loss = 0.501, persamaan garis 1.73x + 1.73y + -1.75 = 0
# epoch = 30, loss = 0.498, persamaan garis 1.76x + 1.76y + -1.78 = 0
# epoch = 31, loss = 0.495, persamaan garis 1.80x + 1.80y + -1.81 = 0
# epoch = 32, loss = 0.493, persamaan garis 1.83x + 1.83y + -1.84 = 0
# epoch = 33, loss = 0.490, persamaan garis 1.86x + 1.86y + -1.87 = 0
# epoch = 34, loss = 0.487, persamaan garis 1.89x + 1.89y + -1.90 = 0
# epoch = 35, loss = 0.485, persamaan garis 1.92x + 1.92y + -1.93 = 0
# epoch = 36, loss = 0.482, persamaan garis 1.95x + 1.95y + -1.96 = 0
# epoch = 37, loss = 0.479, persamaan garis 1.98x + 1.98y + -1.99 = 0
# epoch = 38, loss = 0.477, persamaan garis 2.01x + 2.01y + -2.02 = 0
# epoch = 39, loss = 0.474, persamaan garis 2.04x + 2.04y + -2.05 = 0
# epoch = 40, loss = 0.472, persamaan garis 2.07x + 2.07y + -2.08 = 0
# epoch = 41, loss = 0.470, persamaan garis 2.10x + 2.10y + -2.11 = 0
# epoch = 42, loss = 0.467, persamaan garis 2.13x + 2.13y + -2.14 = 0
# epoch = 43, loss = 0.465, persamaan garis 2.15x + 2.15y + -2.17 = 0
# epoch = 44, loss = 0.463, persamaan garis 2.18x + 2.18y + -2.20 = 0
# epoch = 45, loss = 0.460, persamaan garis 2.21x + 2.21y + -2.22 = 0
# epoch = 46, loss = 0.458, persamaan garis 2.24x + 2.24y + -2.25 = 0
# epoch = 47, loss = 0.456, persamaan garis 2.27x + 2.27y + -2.28 = 0
# epoch = 48, loss = 0.454, persamaan garis 2.29x + 2.29y + -2.31 = 0
# epoch = 49, loss = 0.452, persamaan garis 2.32x + 2.32y + -2.33 = 0
# epoch = 50, loss = 0.450, persamaan garis 2.35x + 2.35y + -2.36 = 0
# epoch = 51, loss = 0.448, persamaan garis 2.37x + 2.37y + -2.39 = 0
# epoch = 52, loss = 0.446, persamaan garis 2.40x + 2.40y + -2.41 = 0
# epoch = 53, loss = 0.444, persamaan garis 2.43x + 2.43y + -2.44 = 0
# epoch = 54, loss = 0.442, persamaan garis 2.45x + 2.45y + -2.47 = 0
# epoch = 55, loss = 0.440, persamaan garis 2.48x + 2.48y + -2.49 = 0
# epoch = 56, loss = 0.438, persamaan garis 2.50x + 2.50y + -2.52 = 0
# epoch = 57, loss = 0.436, persamaan garis 2.53x + 2.53y + -2.54 = 0
# epoch = 58, loss = 0.434, persamaan garis 2.55x + 2.55y + -2.57 = 0
# epoch = 59, loss = 0.432, persamaan garis 2.58x + 2.58y + -2.59 = 0
# epoch = 60, loss = 0.430, persamaan garis 2.60x + 2.60y + -2.62 = 0
# epoch = 61, loss = 0.429, persamaan garis 2.63x + 2.63y + -2.64 = 0
# epoch = 62, loss = 0.427, persamaan garis 2.65x + 2.65y + -2.67 = 0
# epoch = 63, loss = 0.425, persamaan garis 2.68x + 2.68y + -2.69 = 0
# epoch = 64, loss = 0.423, persamaan garis 2.70x + 2.70y + -2.72 = 0
# epoch = 65, loss = 0.422, persamaan garis 2.73x + 2.73y + -2.74 = 0
# epoch = 66, loss = 0.420, persamaan garis 2.75x + 2.75y + -2.77 = 0
# epoch = 67, loss = 0.418, persamaan garis 2.77x + 2.77y + -2.79 = 0
# epoch = 68, loss = 0.417, persamaan garis 2.80x + 2.80y + -2.81 = 0
# epoch = 69, loss = 0.415, persamaan garis 2.82x + 2.82y + -2.84 = 0
# epoch = 70, loss = 0.413, persamaan garis 2.84x + 2.84y + -2.86 = 0
# epoch = 71, loss = 0.412, persamaan garis 2.87x + 2.87y + -2.88 = 0
# epoch = 72, loss = 0.410, persamaan garis 2.89x + 2.89y + -2.91 = 0
# epoch = 73, loss = 0.409, persamaan garis 2.91x + 2.91y + -2.93 = 0
# epoch = 74, loss = 0.407, persamaan garis 2.94x + 2.94y + -2.95 = 0
# epoch = 75, loss = 0.406, persamaan garis 2.96x + 2.96y + -2.98 = 0
# epoch = 76, loss = 0.404, persamaan garis 2.98x + 2.98y + -3.00 = 0
# epoch = 77, loss = 0.403, persamaan garis 3.00x + 3.00y + -3.02 = 0
# epoch = 78, loss = 0.401, persamaan garis 3.02x + 3.02y + -3.04 = 0
# epoch = 79, loss = 0.400, persamaan garis 3.05x + 3.05y + -3.07 = 0
# epoch = 80, loss = 0.399, persamaan garis 3.07x + 3.07y + -3.09 = 0
# epoch = 81, loss = 0.397, persamaan garis 3.09x + 3.09y + -3.11 = 0
# epoch = 82, loss = 0.396, persamaan garis 3.11x + 3.11y + -3.13 = 0
# epoch = 83, loss = 0.394, persamaan garis 3.13x + 3.13y + -3.15 = 0
# epoch = 84, loss = 0.393, persamaan garis 3.15x + 3.15y + -3.17 = 0
# epoch = 85, loss = 0.392, persamaan garis 3.17x + 3.17y + -3.20 = 0
# epoch = 86, loss = 0.390, persamaan garis 3.20x + 3.20y + -3.22 = 0
# epoch = 87, loss = 0.389, persamaan garis 3.22x + 3.22y + -3.24 = 0
# epoch = 88, loss = 0.388, persamaan garis 3.24x + 3.24y + -3.26 = 0
# epoch = 89, loss = 0.387, persamaan garis 3.26x + 3.26y + -3.28 = 0
# epoch = 90, loss = 0.385, persamaan garis 3.28x + 3.28y + -3.30 = 0
# epoch = 91, loss = 0.384, persamaan garis 3.30x + 3.30y + -3.32 = 0
# epoch = 92, loss = 0.383, persamaan garis 3.32x + 3.32y + -3.34 = 0
# epoch = 93, loss = 0.382, persamaan garis 3.34x + 3.34y + -3.36 = 0
# epoch = 94, loss = 0.380, persamaan garis 3.36x + 3.36y + -3.38 = 0
# epoch = 95, loss = 0.379, persamaan garis 3.38x + 3.38y + -3.40 = 0
# epoch = 96, loss = 0.378, persamaan garis 3.40x + 3.40y + -3.42 = 0
# epoch = 97, loss = 0.377, persamaan garis 3.42x + 3.42y + -3.44 = 0
# epoch = 98, loss = 0.376, persamaan garis 3.44x + 3.44y + -3.46 = 0
# epoch = 99, loss = 0.375, persamaan garis 3.46x + 3.46y + -3.48 = 0
# epoch = 100, loss = 0.373, persamaan garis 3.48x + 3.48y + -3.50 = 0
# epoch = 101, loss = 0.372, persamaan garis 3.50x + 3.50y + -3.52 = 0
# epoch = 102, loss = 0.371, persamaan garis 3.52x + 3.52y + -3.54 = 0
# epoch = 103, loss = 0.370, persamaan garis 3.53x + 3.53y + -3.56 = 0
# epoch = 104, loss = 0.369, persamaan garis 3.55x + 3.55y + -3.58 = 0
# epoch = 105, loss = 0.368, persamaan garis 3.57x + 3.57y + -3.60 = 0
# epoch = 106, loss = 0.367, persamaan garis 3.59x + 3.59y + -3.62 = 0
# epoch = 107, loss = 0.366, persamaan garis 3.61x + 3.61y + -3.64 = 0
# epoch = 108, loss = 0.365, persamaan garis 3.63x + 3.63y + -3.66 = 0
# epoch = 109, loss = 0.364, persamaan garis 3.65x + 3.65y + -3.68 = 0
# epoch = 110, loss = 0.363, persamaan garis 3.67x + 3.67y + -3.70 = 0
# epoch = 111, loss = 0.362, persamaan garis 3.68x + 3.68y + -3.71 = 0
# epoch = 112, loss = 0.361, persamaan garis 3.70x + 3.70y + -3.73 = 0
# epoch = 113, loss = 0.360, persamaan garis 3.72x + 3.72y + -3.75 = 0
# epoch = 114, loss = 0.359, persamaan garis 3.74x + 3.74y + -3.77 = 0
# epoch = 115, loss = 0.358, persamaan garis 3.76x + 3.76y + -3.79 = 0
# epoch = 116, loss = 0.357, persamaan garis 3.77x + 3.77y + -3.81 = 0
# epoch = 117, loss = 0.356, persamaan garis 3.79x + 3.79y + -3.82 = 0
# epoch = 118, loss = 0.355, persamaan garis 3.81x + 3.81y + -3.84 = 0
# epoch = 119, loss = 0.354, persamaan garis 3.83x + 3.83y + -3.86 = 0
# epoch = 120, loss = 0.353, persamaan garis 3.84x + 3.84y + -3.88 = 0
# epoch = 121, loss = 0.352, persamaan garis 3.86x + 3.86y + -3.90 = 0
# epoch = 122, loss = 0.351, persamaan garis 3.88x + 3.88y + -3.91 = 0
# epoch = 123, loss = 0.350, persamaan garis 3.90x + 3.90y + -3.93 = 0
# epoch = 124, loss = 0.349, persamaan garis 3.91x + 3.91y + -3.95 = 0
# epoch = 125, loss = 0.349, persamaan garis 3.93x + 3.93y + -3.97 = 0
# epoch = 126, loss = 0.348, persamaan garis 3.95x + 3.95y + -3.98 = 0
# epoch = 127, loss = 0.347, persamaan garis 3.96x + 3.96y + -4.00 = 0
# epoch = 128, loss = 0.346, persamaan garis 3.98x + 3.98y + -4.02 = 0
# epoch = 129, loss = 0.345, persamaan garis 4.00x + 4.00y + -4.04 = 0
# epoch = 130, loss = 0.344, persamaan garis 4.01x + 4.01y + -4.05 = 0
# epoch = 131, loss = 0.343, persamaan garis 4.03x + 4.03y + -4.07 = 0
# epoch = 132, loss = 0.343, persamaan garis 4.05x + 4.05y + -4.09 = 0
# epoch = 133, loss = 0.342, persamaan garis 4.06x + 4.06y + -4.10 = 0
# epoch = 134, loss = 0.341, persamaan garis 4.08x + 4.08y + -4.12 = 0
# epoch = 135, loss = 0.340, persamaan garis 4.10x + 4.10y + -4.14 = 0
# epoch = 136, loss = 0.339, persamaan garis 4.11x + 4.11y + -4.15 = 0
# epoch = 137, loss = 0.338, persamaan garis 4.13x + 4.13y + -4.17 = 0
# epoch = 138, loss = 0.338, persamaan garis 4.15x + 4.15y + -4.19 = 0
# epoch = 139, loss = 0.337, persamaan garis 4.16x + 4.16y + -4.20 = 0
# epoch = 140, loss = 0.336, persamaan garis 4.18x + 4.18y + -4.22 = 0
# epoch = 141, loss = 0.335, persamaan garis 4.19x + 4.19y + -4.24 = 0
# epoch = 142, loss = 0.335, persamaan garis 4.21x + 4.21y + -4.25 = 0
# epoch = 143, loss = 0.334, persamaan garis 4.23x + 4.23y + -4.27 = 0
# epoch = 144, loss = 0.333, persamaan garis 4.24x + 4.24y + -4.28 = 0
# epoch = 145, loss = 0.332, persamaan garis 4.26x + 4.26y + -4.30 = 0
# epoch = 146, loss = 0.332, persamaan garis 4.27x + 4.27y + -4.32 = 0
# epoch = 147, loss = 0.331, persamaan garis 4.29x + 4.29y + -4.33 = 0
# epoch = 148, loss = 0.330, persamaan garis 4.30x + 4.30y + -4.35 = 0
# epoch = 149, loss = 0.329, persamaan garis 4.32x + 4.32y + -4.36 = 0
# epoch = 150, loss = 0.329, persamaan garis 4.33x + 4.33y + -4.38 = 0
# epoch = 151, loss = 0.328, persamaan garis 4.35x + 4.35y + -4.40 = 0
# epoch = 152, loss = 0.327, persamaan garis 4.36x + 4.36y + -4.41 = 0
# epoch = 153, loss = 0.327, persamaan garis 4.38x + 4.38y + -4.43 = 0
# epoch = 154, loss = 0.326, persamaan garis 4.40x + 4.40y + -4.44 = 0
# epoch = 155, loss = 0.325, persamaan garis 4.41x + 4.41y + -4.46 = 0
# epoch = 156, loss = 0.324, persamaan garis 4.43x + 4.43y + -4.47 = 0
# epoch = 157, loss = 0.324, persamaan garis 4.44x + 4.44y + -4.49 = 0
# epoch = 158, loss = 0.323, persamaan garis 4.46x + 4.46y + -4.50 = 0
# epoch = 159, loss = 0.322, persamaan garis 4.47x + 4.47y + -4.52 = 0
# epoch = 160, loss = 0.322, persamaan garis 4.48x + 4.48y + -4.53 = 0
# epoch = 161, loss = 0.321, persamaan garis 4.50x + 4.50y + -4.55 = 0
# epoch = 162, loss = 0.320, persamaan garis 4.51x + 4.51y + -4.56 = 0
# epoch = 163, loss = 0.320, persamaan garis 4.53x + 4.53y + -4.58 = 0
# epoch = 164, loss = 0.319, persamaan garis 4.54x + 4.54y + -4.59 = 0
# epoch = 165, loss = 0.319, persamaan garis 4.56x + 4.56y + -4.61 = 0
# epoch = 166, loss = 0.318, persamaan garis 4.57x + 4.57y + -4.62 = 0
# epoch = 167, loss = 0.317, persamaan garis 4.59x + 4.59y + -4.64 = 0
# epoch = 168, loss = 0.317, persamaan garis 4.60x + 4.60y + -4.65 = 0
# epoch = 169, loss = 0.316, persamaan garis 4.62x + 4.62y + -4.67 = 0
# epoch = 170, loss = 0.315, persamaan garis 4.63x + 4.63y + -4.68 = 0
# epoch = 171, loss = 0.315, persamaan garis 4.64x + 4.64y + -4.70 = 0
# epoch = 172, loss = 0.314, persamaan garis 4.66x + 4.66y + -4.71 = 0
# epoch = 173, loss = 0.314, persamaan garis 4.67x + 4.67y + -4.72 = 0
# epoch = 174, loss = 0.313, persamaan garis 4.69x + 4.69y + -4.74 = 0
# epoch = 175, loss = 0.312, persamaan garis 4.70x + 4.70y + -4.75 = 0
# epoch = 176, loss = 0.312, persamaan garis 4.71x + 4.71y + -4.77 = 0
# epoch = 177, loss = 0.311, persamaan garis 4.73x + 4.73y + -4.78 = 0
# epoch = 178, loss = 0.311, persamaan garis 4.74x + 4.74y + -4.80 = 0
# epoch = 179, loss = 0.310, persamaan garis 4.76x + 4.76y + -4.81 = 0
# epoch = 180, loss = 0.309, persamaan garis 4.77x + 4.77y + -4.82 = 0
# epoch = 181, loss = 0.309, persamaan garis 4.78x + 4.78y + -4.84 = 0
# epoch = 182, loss = 0.308, persamaan garis 4.80x + 4.80y + -4.85 = 0
# epoch = 183, loss = 0.308, persamaan garis 4.81x + 4.81y + -4.87 = 0
# epoch = 184, loss = 0.307, persamaan garis 4.82x + 4.82y + -4.88 = 0
# epoch = 185, loss = 0.307, persamaan garis 4.84x + 4.84y + -4.89 = 0
# epoch = 186, loss = 0.306, persamaan garis 4.85x + 4.85y + -4.91 = 0
# epoch = 187, loss = 0.305, persamaan garis 4.86x + 4.86y + -4.92 = 0
# epoch = 188, loss = 0.305, persamaan garis 4.88x + 4.88y + -4.93 = 0
# epoch = 189, loss = 0.304, persamaan garis 4.89x + 4.89y + -4.95 = 0
# epoch = 190, loss = 0.304, persamaan garis 4.90x + 4.90y + -4.96 = 0
# epoch = 191, loss = 0.303, persamaan garis 4.92x + 4.92y + -4.98 = 0
# epoch = 192, loss = 0.303, persamaan garis 4.93x + 4.93y + -4.99 = 0
# epoch = 193, loss = 0.302, persamaan garis 4.94x + 4.94y + -5.00 = 0
# epoch = 194, loss = 0.302, persamaan garis 4.96x + 4.96y + -5.02 = 0
# epoch = 195, loss = 0.301, persamaan garis 4.97x + 4.97y + -5.03 = 0
# epoch = 196, loss = 0.301, persamaan garis 4.98x + 4.98y + -5.04 = 0
# epoch = 197, loss = 0.300, persamaan garis 5.00x + 5.00y + -5.06 = 0
# epoch = 198, loss = 0.300, persamaan garis 5.01x + 5.01y + -5.07 = 0
# epoch = 199, loss = 0.299, persamaan garis 5.02x + 5.02y + -5.08 = 0

# %% [markdown]
# # 6. Kesimpulan
#
# Kita bisa lihat dari _snippet code_ diatas, error function kita memberikan nilai _loss_ yang semakin lama semakin kecil. Itu menunjukkan bahwa persamaan garis yang kita dapatkan semakin tepat melakukan klasifikasi poin biru dan poin merah kita.
#
# Kita juga bisa melihat performa ANN kita secara kualitatif, yakni dari visualisasi yang muncul. Garis berwarna hijau putus-putus merupakan garis batas yang diestimasikan oleh ANN. Kita dapat melihat bahwa garis tersebut berangsur-angsur memisahkan kelompok poin biru dan merah dengan baik.
#
# Pada akhirnya, dengan menggunakan ANN, kita bisa melakukan estimasi persamaan garis, yakni nilai yang tertera pada baris akhir dari output snippet diatas
